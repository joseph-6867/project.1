# %%
# !pip install gradio

# %%
import gradio as gr
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# %%
data = {
    "Hours": [1,2,3,4,5,6,7,8],
    "Marks": [35,40,50,55,65,70,80,90],
    "Result": [0,0,0,1,1,1,1,1]
}
df = pd.DataFrame(data)

# %%
X = df[["Hours","Marks"]]
y = df["Result"]
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
def predict_result(hours, marks):

    prediction = model.predict([[hours, marks]])

    if prediction[0] == 1:
        return "Student Will Pass"

    else:
        return "Student Will Fail"

# %%
app = gr.Interface(
    fn=predict_result,
    inputs=[
        gr.Slider(1,10,label="Study Hours"),
        gr.Slider(1,100,label="Marks")
    ],
    outputs="text",
    title="Student Result Prediction App"
)

app.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://57354bfaa85fe5270c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://57354bfaa85fe5270c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
